# %%
from parsers.comment import CommentParser

parser = CommentParser()
parser.set_comments()
comments = parser.comments
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-2-8637cb765019> in <module>
#       2
#       3 parser = CommentParser()
# ----> 4 parser.set_comments()
#       5 comments = parser.comments
#
# c:\Users\andhr\Documents\Python\FacebookData\parsers\comment.py in set_comments(self, limit)
#      21         else:
#      22             comments = read_json(COMMENTS_OUTPUT)
# ---> 23             self._set_comments(comments[:limit])
#      24
#      25     def _set_comments(self, comments):
#
# c:\Users\andhr\Documents\Python\FacebookData\parsers\comment.py in _set_comments(self, comments)
#      29         for comment in comments:
#      30             comm = Comment(**comment)
# ---> 31             comm = self.process_data(comm)
#      32             # test.add(comm.target_post)
#      33             self.comments.append(comm)
#
# c:\Users\andhr\Documents\Python\FacebookData\parsers\comment.py in process_data(self, comment)
#      84
#      85     def process_data(self, comment):
# ---> 86         comment.process_title()
#      87         return comment
#      88
#
# c:\Users\andhr\Documents\Python\FacebookData\stage\comment.py in process_title(self)
#      55                 target_user = ' '.join(processing_split[1:])
#      56                 self.target_post = POST_NAME[post_name]
# ---> 57                 self.target_user = get_comment_target_user(target_user)
#      58
#      59
#
# c:\Users\andhr\Documents\Python\FacebookData\db\user.py in get_comment_target_user(target_user)
#      33     session = Session()
#      34
# ---> 35     users = session.query(User).all()
#      36     print(users)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\session.py in query(self, *entities, **kwargs)
#    1583         :class:`.Session`."""
#    1584
# -> 1585         return self._query_cls(entities, self, **kwargs)
#    1586
#    1587     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in __init__(self, entities, session)
#     195         self.session = session
#     196         self._polymorphic_adapters = {}
# --> 197         self._set_entities(entities)
#     198
#     199     def _set_entities(self, entities, entity_wrapper=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in _set_entities(self, entities, entity_wrapper)
#     223                 entity_wrapper(self, ent)
#     224
# --> 225             self._set_entity_selectables(self._entities)
#     226
#     227     def _set_entity_selectables(self, entities):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in _set_entity_selectables(self, entities)
#     254
#     255                     d[entity] = (ext_info, aliased_adapter)
# --> 256                 ent.setup_entity(*d[entity])
#     257
#     258     def _mapper_loads_polymorphically_with(self, mapper, adapter):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\query.py in setup_entity(self, ext_info, aliased_adapter)
#    4322         self.selectable = ext_info.selectable
#    4323         self.is_aliased_class = ext_info.is_aliased_class
# -> 4324         self._with_polymorphic = ext_info.with_polymorphic_mappers
#    4325         self._polymorphic_discriminator = ext_info.polymorphic_on
#    4326         self.entity_zero = ext_info
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __get__(self, obj, cls)
#     882         if obj is None:
#     883             return self
# --> 884         obj.__dict__[self.__name__] = result = self.fget(obj)
#     885         return result
#     886
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\mapper.py in _with_polymorphic_mappers(self)
#    2153     def _with_polymorphic_mappers(self):
#    2154         if Mapper._new_mappers:
# -> 2155             configure_mappers()
#    2156         if not self.with_polymorphic:
#    2157             return []
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\orm\mapper.py in configure_mappers()
#    3293                     )
#    3294                     e._configure_failed = mapper._configure_failed
# -> 3295                     raise e
#    3296
#    3297                 if not mapper.configured:
#
# InvalidRequestError: One or more mappers failed to initialize - can't proceed with initialization of other mappers. Triggering mapper: 'mapped class User->users'. Original exception was: When initializing mapper mapped class User->users, expression 'ConversationParticipants' failed to locate a name ('ConversationParticipants'). If this is a class name, consider adding this relationship() to the <class 'db.user.User'> class after both dependent classes have been defined.

# %%
for comment in comments:
    comment.process_title()
# Out:
# javu Josipe Jukić Rosandić
# objavu Mate Tomljenovića
# objavu Lovra Misaka
# objavu Josipe Jukić Rosandić
# objavu Luane Božić
# objavu Luane Božić
# odgovara na komentar Milana Vojnica Hajduka
# objavu Nevena Marovica
# objavu Nevena Marovica
# fotografiju KLUB Ljubitelja TOMOS Motora
# fotografiju KLUB Ljubitelja TOMOS Motora
# objavu Marija Sekulića
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Antee Hrelje
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Luane Božić
# objavu Luane Božić
# objavu Dejana Lackovića
# objavu Dejana Lackovića
# objavu Dejana Lackovića
# objavu Ivana Šimona
# objavu Viktora Peršića
# fotografiju Mihajla Škoke
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Marka Ozdanovca
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Rejo Noche
# fotografiju Marije Milisic
# objavu Viktora Peršića
# objavu Viktora Peršića
# objavu Viktora Peršića
# objavu Viktora Peršića
# objavu Viktora Peršića
# objavu Viktora Peršića
# objavu BoRne Bužonje
# objavu Bojana Kolarića
# objavu Luane Božić
# objavu Maje Đuričić
# objavu Krunoslava Šimunčića
# objavu Krunoslava Šimunčića
# objavu Kristijana Pečarića
# objavu Luane Božić
# objavu Katije Gjergjaj
# objavu Bojana Kolarića
# objavu Bojana Kolarića
# objavu Bojana Kolarića
# objavu Luane Božić
# objavu Luane Božić
# objavu Ivana Kuftića
# objavu Tomija Marđetke
# objavu Darija Daraca Blažina
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Dejana Bire
# objavu Tomija Marđetke
# objavu Tomija Marđetke
# objavu Tomija Marđetke
# objavu Tomija Marđetke
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mistra BekŽe
# objavu Mate Tomljenovića
# objavu Tomislava Sirotića
# objavu Josipe Jukić Rosandić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# objavu Žanpjera Fole
# Istra News
# objavu KLUB Ljubitelja TOMOS Motora
# objavu Sanje Bozic
# objavu Sanje Bozic
# objavu Rejo Noche
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Luane Božić
# objavu Luane Božić
# fotografiju KLUB Ljubitelja TOMOS Motora
# objavu Filippe Stojanovskog
# objavu Stjepana Antoliša
# objavu Stjepana Antoliša
# objavu Rejo Noche
# objavu Mattea Bradicica
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Maje Marinovic
# objavu Maje Marinovic
# objavu Maje Marinovic
# objavu Maje Marinovic
# objavu Zorana Župana
# objavu Paola Circote
# objavu Paola Circote
# objavu Paola Circote
# objavu Paola Circote
# objavu Paola Circote
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# fotografiju KLUB Ljubitelja TOMOS Motora
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Dade Zagorec
# objavu Dade Zagorec
# fotografiju KLUB Ljubitelja TOMOS Motora
# objavu Dade Zagorec
# objavu Dade Zagorec
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Janka Brezovića
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Ivana Černje
# objavu Davida Pokrajca
# objavu Marka Ozdanovca
# objavu Marka Ozdanovca
# objavu Marka Ozdanovca
# objavu Marka Ozdanovca
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Ivana Šimona
# objavu Bojana Tajkune
# objavu Ivana Černje
# objavu Davida Pokrajca
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Davida Pokrajca
# objavu Rejo Noche
# objavu Luane Božić
# objavu Luane Božić
# objavu Tangchla Doe
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# fotografiju Edija Bakše
# objavu Ivana Tijana
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Josipe Jukić Rosandić
# objavu Filippe Stojanovskog
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Luane Božić
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# vezu Ivana Černje
# objavu Rejo Noche
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Rejo Noche
# objavu Luke Zaharije
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Josipe Jukić Rosandić
# objavu Katije Gjergjaj
# objavu Gustija Dvajstrija Ultrasa
# objavu Gustija Dvajstrija Ultrasa
# objavu Gustija Dvajstrija Ultrasa
# objavu Filippe Stojanovskog
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Luke Zaharije
# objavu Luchasa Nadija
# objavu Luchasa Nadija
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu NK Barbana
# Istra News
# objavu Danijela Pleše
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Davida Pokrajca
# objavu Luke Zaharije
# objavu Marinića Mihaela
# objavu Ivana Tijana
# objavu Rejo Noche
# objavu Josipe Brstilo
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Luchasa Nadija
# objavu Luane Božić
# objavu Ivana Černje
# objavu Leonarda Žulića
# objavu Leonarda Žulića
# objavu Leonarda Žulića
# objavu Leonarda Žulića
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Ivana Habazina
# objavu Ivana Habazina
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Filippe Stojanovskog
# objavu Brune Rukelja
# objavu Brune Rukelja
# videozapis Croatian Vines
# videozapis Žanpjera Fole
# objavu Katije Gjergjaj
# videozapis Žanpjera Fole
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# videozapis Žanpjera Fole
# videozapis Žanpjera Fole
# videozapis Žanpjera Fole
# videozapis Žanpjera Fole
# objavu Nikole Jurišića
# objavu Petra Riseka
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Jasmina Mikec
# objavu Brune Rukelja
# objavu Matej Kusaka
# objavu Matej Kusaka
# objavu Matej Kusaka
# objavu Marinića Mihaela
# objavu Marinića Mihaela
# objavu Marinića Mihaela
# objavu Alena Ercega
# objavu Daniela Benke
# objavu Brune Rukelja
# objavu Brune Rukelja
# objavu Danijela Pleše
# objavu Danijela Pleše
# objavu Rejo Noche
# objavu Matea Otocana
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Alana Šimića
# objavu Pamele Milotić
# objavu Pamele Milotić
# objavu Josipa Jelene
# objavu Josipa Jelene
# objavu Alena Ercega
# objavu Alena Ercega
# objavu Alena Ercega
# objavu Alena Ercega
# objavu Pijere Zohila
# objavu Ivana Juračića
# objavu Pijere Zohila
# objavu Pijere Zohila
# objavu Darija Vukovića
# objavu Borisa Vuka
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# fotografiju Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Josipe Jukić Rosandić
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Luane Božić
# objavu Luane Božić
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Denisa Kalača
# objavu Denisa Kalača
# objavu Katije Gjergjaj
# objavu Davora Ledencana
# objavu Marinića Mihaela
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Ivana Černje
# objavu Šimuna Radoša
# objavu Šimuna Radoša
# objavu Josipe Jukić Rosandić
# objavu Janka Brezovića
# objavu Szebasztiana Fatyola
# objavu Filippe Stojanovskog
# objavu Brune Munjića
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Rejo Noche
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Lare Božac
# objavu Lare Božac
# objavu Lare Božac
# objavu Luane Božić
# objavu Katije Gjergjaj
# objavu Luane Božić
# objavu Luane Božić
# fotografiju Roberte Špoljarić
# fotografiju Roberte Špoljarić
# fotografiju Roberte Špoljarić
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Rejo Noche
# objavu Rejo Noche
# fotografiju Ivana Černje
# objavu Rejo Noche
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# fotografiju Pamele Milotić
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Rejo Noche
# vezu Daniela Armande
# objavu Luane Božić
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Matea Otocana
# objavu Spotted: Rovinj
# objavu Spotted: Rovinj
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Spotted: Rovinj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Katije Gjergjaj
# objavu Matej Pausa
# objavu Matej Pausa
# objavu Rejo Noche
# objavu Luane Božić
# objavu Luane Božić
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Luane Božić
# objavu Rejo Noche
# objavu Luane Božić
# objavu Luane Božić
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Ivana Tijana
# fotografiju Nikoline Đerki
# fotografiju Masime Herića
# objavu Marsela FullHouse
# objavu Rejo Noche
# fotografiju Ivana Černje
# fotografiju Ivana Černje
# fotografiju Ivana Černje
# objavu Ivana Černje
# objavu Davida Pokrajca
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Černje
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Ivana Tijana
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Davida Pokrajca
# objavu Žanpjera Fole
# objavu Maje Đuričić
# objavu Rejo Noche
# objavu Maje Đuričić
# objavu Daniela Ćosića
# objavu Daniela Ćosića
# objavu Daniela Ćosića
# objavu Daniela Ćosića
# objavu Daniela Ćosića
# objavu Matej Fakina
# objavu Luane Božić
# objavu Luane Božić
# objavu Daniela Ćosića
# objavu Luane Božić
# objavu Luane Božić
# objavu Luane Božić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Josipe Jukić Rosandić
# objavu Davida Pokrajca
# objavu Daniela Armande
# objavu Daniela Armande
# objavu Davida Pokrajca
# objavu Luane Božić
# objavu Luane Božić
# objavu Rejo Noche
# objavu Katije Gjergjaj
# fotografiju Alberte Bartulića
# objavu Luane Božić
# objavu Luane Božić
# fotografiju Ivana Tijana
# fotografiju Nikoline Đerki
# fotografiju Nikoline Đerki
# objavu Žanpjera Fole
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Ivana Prenija Babića
# objavu Doris OtoČan
# fotografiju Matej Pausa
# objavu Elene Rudan
# objavu Elene Rudan
# objavu Dionore Roce
# objavu Elene Rudan
# objavu Elene Rudan
# objavu Mihaele Stanković
# objavu Mihaele Stanković
# objavu Lare Božac
# objavu Dionore Roce
# objavu Lare Božac
# objavu Lare Božac
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Teute Benčić
# objavu Elene Rudan
# objavu Elene Rudan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Lare Božac
# objavu Doris OtoČan
# objavu OK je OK!
# objavu Lare Božac
# objavu Valentine Križman
# objavu Valentine Križman
# objavu Dionore Roce
# objavu Lare Božac
# objavu Doris OtoČan
# objavu Lare Božac
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# vezu Dionore Roce
# vezu Dionore Roce
# vezu Dionore Roce
# objavu Lare Božac
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Ivane Karlović
# objavu Đeni Aničić
# objavu Pijere Zohila
# objavu Ivane Karlović
# objavu Johanne Rossmanit
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Elene Cekic
# objavu Lare Božac
# objavu OK je OK!
# objavu Valentine Križman
# objavu Višnje Pucić
# objavu Elene Rudan
# objavu Elene Nezic
# objavu Andree Rojnic
# objavu Andree Rojnic
# objavu Andree Rojnic
# objavu Andree Rojnic
# objavu Valentine Križman
# objavu Doris OtoČan
# objavu Ivana Zaharije
# objavu Elene Rudan
# objavu Elene Rudan
# objavu Janija Pamića
# objavu Maure Frančule
# objavu Endija Vidulina
# objavu Monike Brozan
# objavu Monike Brozan
# objavu Simone Matošović
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Valentine Križman
# bilješku od Istra News
# objavu Lare Božac
# objavu Ivane Karlović
# objavu OK je OK!
# objavu Johanne Rossmanit
# objavu Elene Rudan
# objavu Dade Putine
# svoj poveznicu
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Izbor za najljepše oči^^
# svoj poveznicu
# svoj poveznicu
# objavu Valentine Vičić
# objavu Valentine Vičić
# fotografiju Izbor za najljepše oči^^
# objavu Matee Nine
# objavu Lare Božac
# svoj poveznicu
# objavu Janija Pamića
# objavu Mrzim kad mi citaju poruke na mobitelu --
# objavu Đanija Guština
# objavu Alessije Stelko
# objavu Lare Božac
# objavu Lare Božac
# objavu Lare Božac
# objavu Lare Božac
# objavu Lare Božac
# objavu Tonija Matoševića
# objavu Tonija Matoševića
# objavu Lare Božac
# bilješku od Ivana Karlić
# bilješku od Ivana Karlić
# bilješku od Ivana Karlić
# objavu Lare Božac
# objavu Ivana Prenija Babića
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Doris OtoČan
# objavu Lare Božac
# objavu Lare Božac
# objavu Ivana Prenija Babića
# objavu Lare Božac
# objavu Doris OtoČan
# objavu Izbor za najljepšu curu
# objavu Lare Božac
# vezu Justin Bieber
# bilješku od Doris OtoČan
# objavu Lare Božac
# fotografiju Chrisa Ke
# fotografiju Chrisa Ke
# fotografiju Chrisa Ke
# fotografiju Chrisa Ke
# fotografiju Ivana Batela
# objavu Steph Seybert
